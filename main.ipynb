# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
schedule_22 = pd.read_csv('22_schedule.csv')

# %%
schedule_23 = pd.read_csv('23_schedule.csv')

# %%
stats_22 = pd.read_csv('22_team_stats.csv')

# %%
stats_23 = pd.read_csv('23_team_stats.csv')

# %%
schedule_22.tail()
# Out:
#           Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 280   Division  Sun  2023-01-22  3:00PM   Cincinnati Bengals          @
# 281   Division  Sun  2023-01-22  6:30PM  San Francisco 49ers        NaN
# 282  ConfChamp  Sun  2023-01-29  3:00PM  Philadelphia Eagles        NaN
# 283  ConfChamp  Sun  2023-01-29  6:30PM   Kansas City Chiefs        NaN
# 284  SuperBowl  Sun  2023-02-12  6:30PM   Kansas City Chiefs          N
#
#                Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL
# 280        Buffalo Bills   boxscore  27.0  10.0  412.0  0.0  325.0  1.0
# 281       Dallas Cowboys   boxscore  19.0  12.0  312.0  1.0  282.0  2.0
# 282  San Francisco 49ers   boxscore  31.0   7.0  269.0  0.0  164.0  3.0
# 283   Cincinnati Bengals   boxscore  23.0  20.0  357.0  1.0  309.0  2.0
# 284  Philadelphia Eagles   boxscore  38.0  35.0  340.0  0.0  417.0  1.0

# %%
 schedule_22.shape
# Out:
# (285, 14)

# %%
schedule_22['Home'] = schedule_22.apply(
    lambda row: row['Loser/tie'] 
    if row['Unnamed: 5'] == '@' else row['Winner/tie'], 
    axis=1
)

# %%
schedule_22['Away'] = schedule_22.apply(
    lambda row: row['Winner/tie']
    if row['Unnamed: 5'] == '@' else row['Loser/tie'],
    axis=1
)

# %%
schedule_22.shape
# Out:
# (285, 16)

# %%
schedule_22.head()
# Out:
#   Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 0    1  Thu  2022-09-08  8:20PM        Buffalo Bills          @
# 1    1  Sun  2022-09-11  1:00PM   New Orleans Saints          @
# 2    1  Sun  2022-09-11  1:00PM     Cleveland Browns          @
# 3    1  Sun  2022-09-11  1:00PM        Chicago Bears        NaN
# 4    1  Sun  2022-09-11  1:00PM  Pittsburgh Steelers          @
#
#              Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0     Los Angeles Rams   boxscore  31.0  10.0  413.0  4.0  243.0  3.0
# 1      Atlanta Falcons   boxscore  27.0  26.0  385.0  1.0  416.0  2.0
# 2    Carolina Panthers   boxscore  26.0  24.0  355.0  0.0  261.0  1.0
# 3  San Francisco 49ers   boxscore  19.0  10.0  204.0  1.0  331.0  2.0
# 4   Cincinnati Bengals   boxscore  23.0  20.0  267.0  0.0  432.0  5.0
#
#                  Home                 Away
# 0    Los Angeles Rams        Buffalo Bills
# 1     Atlanta Falcons   New Orleans Saints
# ...

# %%
schedule_22.tail()
# Out:
#           Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 280   Division  Sun  2023-01-22  3:00PM   Cincinnati Bengals          @
# 281   Division  Sun  2023-01-22  6:30PM  San Francisco 49ers        NaN
# 282  ConfChamp  Sun  2023-01-29  3:00PM  Philadelphia Eagles        NaN
# 283  ConfChamp  Sun  2023-01-29  6:30PM   Kansas City Chiefs        NaN
# 284  SuperBowl  Sun  2023-02-12  6:30PM   Kansas City Chiefs          N
#
#                Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 280        Buffalo Bills   boxscore  27.0  10.0  412.0  0.0  325.0  1.0
# 281       Dallas Cowboys   boxscore  19.0  12.0  312.0  1.0  282.0  2.0
# 282  San Francisco 49ers   boxscore  31.0   7.0  269.0  0.0  164.0  3.0
# 283   Cincinnati Bengals   boxscore  23.0  20.0  357.0  1.0  309.0  2.0
# 284  Philadelphia Eagles   boxscore  38.0  35.0  340.0  0.0  417.0  1.0
#
#                     Home                 Away
# 280        Buffalo Bills   Cincinnati Bengals
# ...

# %%
schedule_23['Home'] = schedule_23.apply(
    lambda row: row['Loser/tie'] 
    if row['Unnamed: 5'] == '@' else row['Winner/tie'], 
    axis=1
)

# %%
schedule_23['Away'] = schedule_23.apply(
    lambda row: row['Winner/tie']
    if row['Unnamed: 5'] == '@' else row['Loser/tie'],
    axis=1
)

# %%
schedule_23.head()
# Out:
#   Week  Day        Date    Time             Winner/tie Unnamed: 5  \
# 0    1  Thu  2023-09-07  8:20PM          Detroit Lions          @
# 1    1  Sun  2023-09-10  1:00PM        Atlanta Falcons        NaN
# 2    1  Sun  2023-09-10  1:00PM       Cleveland Browns        NaN
# 3    1  Sun  2023-09-10  1:00PM   Jacksonville Jaguars          @
# 4    1  Sun  2023-09-10  1:00PM  Washington Commanders        NaN
#
#             Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0  Kansas City Chiefs   boxscore  21.0  20.0  368.0  1.0  316.0  1.0
# 1   Carolina Panthers   boxscore  24.0  10.0  221.0  0.0  281.0  3.0
# 2  Cincinnati Bengals   boxscore  24.0   3.0  350.0  2.0  142.0  0.0
# 3  Indianapolis Colts   boxscore  31.0  21.0  342.0  2.0  280.0  3.0
# 4   Arizona Cardinals   boxscore  20.0  16.0  248.0  3.0  210.0  2.0
#
#                     Home                  Away
# 0     Kansas City Chiefs         Detroit Lions
# 1        Atlanta Falcons     Carolina Panthers
# ...

# %%
schedule_23.tail()
# Out:
#           Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 281   Division  Sun  2024-01-21  3:00PM        Detroit Lions        NaN
# 282   Division  Sun  2024-01-21  6:30PM   Kansas City Chiefs          @
# 283  ConfChamp  Sun  2024-01-28  3:00PM   Kansas City Chiefs          @
# 284  ConfChamp  Sun  2024-01-28  6:30PM  San Francisco 49ers        NaN
# 285  SuperBowl  Sun  2024-02-11  6:30PM   Kansas City Chiefs          N
#
#                 Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 281  Tampa Bay Buccaneers   boxscore  31.0  23.0  391.0  0.0  408.0  2.0
# 282         Buffalo Bills   boxscore  27.0  24.0  361.0  1.0  368.0  0.0
# 283      Baltimore Ravens   boxscore  17.0  10.0  319.0  0.0  336.0  3.0
# 284         Detroit Lions   boxscore  34.0  31.0  413.0  1.0  442.0  1.0
# 285   San Francisco 49ers   boxscore  25.0  22.0  455.0  2.0  382.0  2.0
#
#                     Home                  Away
# ...

# %%
stats_22.head()
# Out:
#                      Tm   W   L  T   W-L%   PF   PA   PD   MoV  SoS   SRS  \
# 0        Buffalo Bills*  13   3  0  0.813  455  286  169  10.6  0.4  10.9
# 1       Miami Dolphins+   9   8  0  0.529  397  399   -2  -0.1  2.0   1.8
# 2  New England Patriots   8   9  0  0.471  364  347   17   1.0  1.0   2.0
# 3         New York Jets   7  10  0  0.412  296  316  -20  -1.2  2.0   0.8
# 4   Cincinnati Bengals*  12   4  0  0.750  418  322   96   6.0  0.9   6.9
#
#    OSRS  DSRS
# 0   7.1   3.8
# 1   2.7  -0.9
# 2  -0.3   2.3
# 3  -4.0   4.8
# 4   5.5   1.4

# %%
stats_22['Tm'] = stats_22['Tm'].str.replace(r'[\*\+]', '', regex=True)

# %%
stats_23['Tm'] = stats_23['Tm'].str.replace(r'[\*\+]', '', regex=True)

# %%
stats_23.head()
# Out:
#                      Tm   W   L   W-L%   PF   PA   PD   MoV  SoS   SRS  OSRS  \
# 0         Buffalo Bills  11   6  0.647  451  311  140   8.2 -1.8   6.5   4.1
# 1        Miami Dolphins  11   6  0.647  496  391  105   6.2 -1.8   4.4   7.6
# 2         New York Jets   7  10  0.412  268  355  -87  -5.1 -0.6  -5.8  -6.7
# 3  New England Patriots   4  13  0.235  236  366 -130  -7.6 -0.2  -7.9  -8.5
# 4      Baltimore Ravens  13   4  0.765  483  280  203  11.9  1.2  13.2   6.7
#
#    DSRS
# 0   2.3
# 1  -3.1
# 2   0.9
# 3   0.6
# 4   6.5

# %%
schedule_22.head()
# Out:
#   Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 0    1  Thu  2022-09-08  8:20PM        Buffalo Bills          @
# 1    1  Sun  2022-09-11  1:00PM   New Orleans Saints          @
# 2    1  Sun  2022-09-11  1:00PM     Cleveland Browns          @
# 3    1  Sun  2022-09-11  1:00PM        Chicago Bears        NaN
# 4    1  Sun  2022-09-11  1:00PM  Pittsburgh Steelers          @
#
#              Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0     Los Angeles Rams   boxscore  31.0  10.0  413.0  4.0  243.0  3.0
# 1      Atlanta Falcons   boxscore  27.0  26.0  385.0  1.0  416.0  2.0
# 2    Carolina Panthers   boxscore  26.0  24.0  355.0  0.0  261.0  1.0
# 3  San Francisco 49ers   boxscore  19.0  10.0  204.0  1.0  331.0  2.0
# 4   Cincinnati Bengals   boxscore  23.0  20.0  267.0  0.0  432.0  5.0
#
#                  Home                 Away
# 0    Los Angeles Rams        Buffalo Bills
# 1     Atlanta Falcons   New Orleans Saints
# ...

# %%
to_merge = stats_22[['Tm', 'W', 'L', 'W-L%', 'PF', 'PA', 'PD', 'MoV', 'SoS', 'OSRS', 'DSRS']]

# %%
schedule_22 = schedule_22.merge(to_merge, how='left', left_on='Home', right_on='Tm', suffixes=('', '_home'))

# %%
schedule_22.head()
# Out:
#   Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 0    1  Thu  2022-09-08  8:20PM        Buffalo Bills          @
# 1    1  Sun  2022-09-11  1:00PM   New Orleans Saints          @
# 2    1  Sun  2022-09-11  1:00PM     Cleveland Browns          @
# 3    1  Sun  2022-09-11  1:00PM        Chicago Bears        NaN
# 4    1  Sun  2022-09-11  1:00PM  Pittsburgh Steelers          @
#
#              Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0     Los Angeles Rams   boxscore  31.0  10.0  413.0  4.0  243.0  3.0
# 1      Atlanta Falcons   boxscore  27.0  26.0  385.0  1.0  416.0  2.0
# 2    Carolina Panthers   boxscore  26.0  24.0  355.0  0.0  261.0  1.0
# 3  San Francisco 49ers   boxscore  19.0  10.0  204.0  1.0  331.0  2.0
# 4   Cincinnati Bengals   boxscore  23.0  20.0  267.0  0.0  432.0  5.0
#
#                  Home                 Away                  Tm     W     L  \
# 0    Los Angeles Rams        Buffalo Bills    Los Angeles Rams   5.0  12.0
# ...

# %%
schedule_22.tail()
# Out:
#           Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 280   Division  Sun  2023-01-22  3:00PM   Cincinnati Bengals          @
# 281   Division  Sun  2023-01-22  6:30PM  San Francisco 49ers        NaN
# 282  ConfChamp  Sun  2023-01-29  3:00PM  Philadelphia Eagles        NaN
# 283  ConfChamp  Sun  2023-01-29  6:30PM   Kansas City Chiefs        NaN
# 284  SuperBowl  Sun  2023-02-12  6:30PM   Kansas City Chiefs          N
#
#                Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 280        Buffalo Bills   boxscore  27.0  10.0  412.0  0.0  325.0  1.0
# 281       Dallas Cowboys   boxscore  19.0  12.0  312.0  1.0  282.0  2.0
# 282  San Francisco 49ers   boxscore  31.0   7.0  269.0  0.0  164.0  3.0
# 283   Cincinnati Bengals   boxscore  23.0  20.0  357.0  1.0  309.0  2.0
# 284  Philadelphia Eagles   boxscore  38.0  35.0  340.0  0.0  417.0  1.0
#
#                     Home                 Away                   Tm     W    L  \
# ...

# %%
schedule_22.shape
# Out:
# (285, 27)

# %%
schedule_22 = schedule_22.merge(to_merge, how='left', left_on='Away', right_on='Tm', suffixes=('_home', '_away'))

# %%
schedule_22.head()
# Out:
#   Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 0    1  Thu  2022-09-08  8:20PM        Buffalo Bills          @
# 1    1  Sun  2022-09-11  1:00PM   New Orleans Saints          @
# 2    1  Sun  2022-09-11  1:00PM     Cleveland Browns          @
# 3    1  Sun  2022-09-11  1:00PM        Chicago Bears        NaN
# 4    1  Sun  2022-09-11  1:00PM  Pittsburgh Steelers          @
#
#              Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0     Los Angeles Rams   boxscore  31.0  10.0  413.0  4.0  243.0  3.0
# 1      Atlanta Falcons   boxscore  27.0  26.0  385.0  1.0  416.0  2.0
# 2    Carolina Panthers   boxscore  26.0  24.0  355.0  0.0  261.0  1.0
# 3  San Francisco 49ers   boxscore  19.0  10.0  204.0  1.0  331.0  2.0
# 4   Cincinnati Bengals   boxscore  23.0  20.0  267.0  0.0  432.0  5.0
#
#                  Home                 Away             Tm_home  W_home  \
# 0    Los Angeles Rams        Buffalo Bills    Los Angeles Rams     5.0
# ...

# %%
schedule_22.tail()
# Out:
#           Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 280   Division  Sun  2023-01-22  3:00PM   Cincinnati Bengals          @
# 281   Division  Sun  2023-01-22  6:30PM  San Francisco 49ers        NaN
# 282  ConfChamp  Sun  2023-01-29  3:00PM  Philadelphia Eagles        NaN
# 283  ConfChamp  Sun  2023-01-29  6:30PM   Kansas City Chiefs        NaN
# 284  SuperBowl  Sun  2023-02-12  6:30PM   Kansas City Chiefs          N
#
#                Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 280        Buffalo Bills   boxscore  27.0  10.0  412.0  0.0  325.0  1.0
# 281       Dallas Cowboys   boxscore  19.0  12.0  312.0  1.0  282.0  2.0
# 282  San Francisco 49ers   boxscore  31.0   7.0  269.0  0.0  164.0  3.0
# 283   Cincinnati Bengals   boxscore  23.0  20.0  357.0  1.0  309.0  2.0
# 284  Philadelphia Eagles   boxscore  38.0  35.0  340.0  0.0  417.0  1.0
#
#                     Home                 Away              Tm_home  W_home  \
# ...

# %%
schedule_22.drop(columns=['Unnamed: 7', 'Tm_home', 'Tm_away'], inplace=True)

# %%
schedule_22.shape
# Out:
# (285, 35)

# %%
schedule_22.head()
# Out:
#   Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 0    1  Thu  2022-09-08  8:20PM        Buffalo Bills          @
# 1    1  Sun  2022-09-11  1:00PM   New Orleans Saints          @
# 2    1  Sun  2022-09-11  1:00PM     Cleveland Browns          @
# 3    1  Sun  2022-09-11  1:00PM        Chicago Bears        NaN
# 4    1  Sun  2022-09-11  1:00PM  Pittsburgh Steelers          @
#
#              Loser/tie  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0     Los Angeles Rams  31.0  10.0  413.0  4.0  243.0  3.0
# 1      Atlanta Falcons  27.0  26.0  385.0  1.0  416.0  2.0
# 2    Carolina Panthers  26.0  24.0  355.0  0.0  261.0  1.0
# 3  San Francisco 49ers  19.0  10.0  204.0  1.0  331.0  2.0
# 4   Cincinnati Bengals  23.0  20.0  267.0  0.0  432.0  5.0
#
#                  Home                 Away  W_home  L_home  W-L%_home  \
# 0    Los Angeles Rams        Buffalo Bills     5.0    12.0      0.294
# 1     Atlanta Falcons   New Orleans Saints     7.0    10.0      0.412
# ...

# %%
to_merge = stats_23[['Tm', 'W', 'L', 'W-L%', 'PF', 'PA', 'PD', 'MoV', 'SoS', 'OSRS', 'DSRS']]

# %%
schedule_23 = schedule_23.merge(to_merge, how='left', left_on='Home', right_on='Tm', suffixes=('', '_home'))

# %%
schedule_23 = schedule_23.merge(to_merge, how='left', left_on='Away', right_on='Tm', suffixes=('_home', '_away'))

# %%
schedule_23.head()
# Out:
#   Week  Day        Date    Time             Winner/tie Unnamed: 5  \
# 0    1  Thu  2023-09-07  8:20PM          Detroit Lions          @
# 1    1  Sun  2023-09-10  1:00PM        Atlanta Falcons        NaN
# 2    1  Sun  2023-09-10  1:00PM       Cleveland Browns        NaN
# 3    1  Sun  2023-09-10  1:00PM   Jacksonville Jaguars          @
# 4    1  Sun  2023-09-10  1:00PM  Washington Commanders        NaN
#
#             Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0  Kansas City Chiefs   boxscore  21.0  20.0  368.0  1.0  316.0  1.0
# 1   Carolina Panthers   boxscore  24.0  10.0  221.0  0.0  281.0  3.0
# 2  Cincinnati Bengals   boxscore  24.0   3.0  350.0  2.0  142.0  0.0
# 3  Indianapolis Colts   boxscore  31.0  21.0  342.0  2.0  280.0  3.0
# 4   Arizona Cardinals   boxscore  20.0  16.0  248.0  3.0  210.0  2.0
#
#                     Home                  Away                Tm_home  W_home  \
# ...

# %%
schedule_23.tail()
# Out:
#           Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 281   Division  Sun  2024-01-21  3:00PM        Detroit Lions        NaN
# 282   Division  Sun  2024-01-21  6:30PM   Kansas City Chiefs          @
# 283  ConfChamp  Sun  2024-01-28  3:00PM   Kansas City Chiefs          @
# 284  ConfChamp  Sun  2024-01-28  6:30PM  San Francisco 49ers        NaN
# 285  SuperBowl  Sun  2024-02-11  6:30PM   Kansas City Chiefs          N
#
#                 Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 281  Tampa Bay Buccaneers   boxscore  31.0  23.0  391.0  0.0  408.0  2.0
# 282         Buffalo Bills   boxscore  27.0  24.0  361.0  1.0  368.0  0.0
# 283      Baltimore Ravens   boxscore  17.0  10.0  319.0  0.0  336.0  3.0
# 284         Detroit Lions   boxscore  34.0  31.0  413.0  1.0  442.0  1.0
# 285   San Francisco 49ers   boxscore  25.0  22.0  455.0  2.0  382.0  2.0
#
#                     Home                  Away              Tm_home  W_home  \
# ...

# %%
schedule_23.drop(columns=['Unnamed: 7', 'Tm_home', 'Tm_away'], inplace=True)

# %%
schedule_23.head()
# Out:
#   Week  Day        Date    Time             Winner/tie Unnamed: 5  \
# 0    1  Thu  2023-09-07  8:20PM          Detroit Lions          @
# 1    1  Sun  2023-09-10  1:00PM        Atlanta Falcons        NaN
# 2    1  Sun  2023-09-10  1:00PM       Cleveland Browns        NaN
# 3    1  Sun  2023-09-10  1:00PM   Jacksonville Jaguars          @
# 4    1  Sun  2023-09-10  1:00PM  Washington Commanders        NaN
#
#             Loser/tie  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0  Kansas City Chiefs  21.0  20.0  368.0  1.0  316.0  1.0
# 1   Carolina Panthers  24.0  10.0  221.0  0.0  281.0  3.0
# 2  Cincinnati Bengals  24.0   3.0  350.0  2.0  142.0  0.0
# 3  Indianapolis Colts  31.0  21.0  342.0  2.0  280.0  3.0
# 4   Arizona Cardinals  20.0  16.0  248.0  3.0  210.0  2.0
#
#                     Home                  Away  W_home  L_home  W-L%_home  \
# 0     Kansas City Chiefs         Detroit Lions    11.0     6.0      0.647
# ...

# %%
schedule_22.drop(columns=['Unnamed: 5'], inplace=True)

# %%
schedule_23.drop(columns=['Unnamed: 5'], inplace=True)

# %%
schedule_22.head()
# Out:
#   Week  Day        Date    Time           Winner/tie            Loser/tie  \
# 0    1  Thu  2022-09-08  8:20PM        Buffalo Bills     Los Angeles Rams
# 1    1  Sun  2022-09-11  1:00PM   New Orleans Saints      Atlanta Falcons
# 2    1  Sun  2022-09-11  1:00PM     Cleveland Browns    Carolina Panthers
# 3    1  Sun  2022-09-11  1:00PM        Chicago Bears  San Francisco 49ers
# 4    1  Sun  2022-09-11  1:00PM  Pittsburgh Steelers   Cincinnati Bengals
#
#    PtsW  PtsL   YdsW  TOW   YdsL  TOL                Home  \
# 0  31.0  10.0  413.0  4.0  243.0  3.0    Los Angeles Rams
# 1  27.0  26.0  385.0  1.0  416.0  2.0     Atlanta Falcons
# 2  26.0  24.0  355.0  0.0  261.0  1.0   Carolina Panthers
# 3  19.0  10.0  204.0  1.0  331.0  2.0       Chicago Bears
# 4  23.0  20.0  267.0  0.0  432.0  5.0  Cincinnati Bengals
#
#                   Away  W_home  L_home  W-L%_home  PF_home  PA_home  PD_home  \
# 0        Buffalo Bills     5.0    12.0      0.294    307.0    384.0    -77.0
# ...

# %%
schedule_23.head()
# Out:
#   Week  Day        Date    Time             Winner/tie           Loser/tie  \
# 0    1  Thu  2023-09-07  8:20PM          Detroit Lions  Kansas City Chiefs
# 1    1  Sun  2023-09-10  1:00PM        Atlanta Falcons   Carolina Panthers
# 2    1  Sun  2023-09-10  1:00PM       Cleveland Browns  Cincinnati Bengals
# 3    1  Sun  2023-09-10  1:00PM   Jacksonville Jaguars  Indianapolis Colts
# 4    1  Sun  2023-09-10  1:00PM  Washington Commanders   Arizona Cardinals
#
#    PtsW  PtsL   YdsW  TOW   YdsL  TOL                   Home  \
# 0  21.0  20.0  368.0  1.0  316.0  1.0     Kansas City Chiefs
# 1  24.0  10.0  221.0  0.0  281.0  3.0        Atlanta Falcons
# 2  24.0   3.0  350.0  2.0  142.0  0.0       Cleveland Browns
# 3  31.0  21.0  342.0  2.0  280.0  3.0     Indianapolis Colts
# 4  20.0  16.0  248.0  3.0  210.0  2.0  Washington Commanders
#
#                    Away  W_home  L_home  W-L%_home  PF_home  PA_home  PD_home  \
# ...

# %%
schedule_22.dtypes
# Out:
# Week           object
# Day            object
# Date           object
# Time           object
# Winner/tie     object
# Loser/tie      object
# PtsW          float64
# PtsL          float64
# YdsW          float64
# TOW           float64
# YdsL          float64
# TOL           float64
# Home           object
# Away           object
# W_home        float64
# L_home        float64
# W-L%_home     float64
# PF_home       float64
# PA_home       float64
# PD_home       float64
# MoV_home      float64
# SoS_home      float64
# OSRS_home     float64
# DSRS_home     float64
# W_away        float64
# L_away        float64
# W-L%_away     float64
# PF_away       float64
# PA_away       float64
# PD_away       float64
# MoV_away      float64
# SoS_away      float64
# OSRS_away     float64
# DSRS_away     float64
# dtype: object

# %%
ploffs = schedule_22.loc[271]

# %%
print(ploffs)
# Out:
# Week               NaN
# Day                NaN
# Date          Playoffs
# Time               NaN
# Winner/tie         NaN
# Loser/tie          NaN
# PtsW               NaN
# PtsL               NaN
# YdsW               NaN
# TOW                NaN
# YdsL               NaN
# TOL                NaN
# Home               NaN
# Away               NaN
# W_home             NaN
# L_home             NaN
# W-L%_home          NaN
# PF_home            NaN
# PA_home            NaN
# PD_home            NaN
# MoV_home           NaN
# SoS_home           NaN
# OSRS_home          NaN
# DSRS_home          NaN
# W_away             NaN
# L_away             NaN
# W-L%_away          NaN
# PF_away            NaN
# PA_away            NaN
# PD_away            NaN
# MoV_away           NaN
# SoS_away           NaN
# OSRS_away          NaN
# DSRS_away          NaN
# Name: 271, dtype: object

# %%
schedule_22.drop(index=271, inplace=True)

# %%
schedule_22.reset_index(drop=True, inplace=True)

# %%
schedule_22["Date"] = pd.to_datetime(schedule_22["Date"])

# %%
schedule_22.dtypes
# Out:
# Week                  object
# Day                   object
# Date          datetime64[ns]
# Time                  object
# Winner/tie            object
# Loser/tie             object
# PtsW                 float64
# PtsL                 float64
# YdsW                 float64
# TOW                  float64
# YdsL                 float64
# TOL                  float64
# Home                  object
# Away                  object
# W_home               float64
# L_home               float64
# W-L%_home            float64
# PF_home              float64
# PA_home              float64
# PD_home              float64
# MoV_home             float64
# SoS_home             float64
# OSRS_home            float64
# DSRS_home            float64
# W_away               float64
# L_away               float64
# W-L%_away            float64
# PF_away              float64
# PA_away              float64
# PD_away              float64
# MoV_away             float64
# SoS_away             float64
# ...

# %%
schedule_22["Time"] = schedule_22["Time"].str.replace(":.+", "", regex=True).astype("int")

# %%
schedule_22.dtypes
# Out:
# Week                  object
# Day                   object
# Date          datetime64[ns]
# Time                   int32
# Winner/tie            object
# Loser/tie             object
# PtsW                 float64
# PtsL                 float64
# YdsW                 float64
# TOW                  float64
# YdsL                 float64
# TOL                  float64
# Home                  object
# Away                  object
# W_home               float64
# L_home               float64
# W-L%_home            float64
# PF_home              float64
# PA_home              float64
# PD_home              float64
# MoV_home             float64
# SoS_home             float64
# OSRS_home            float64
# DSRS_home            float64
# W_away               float64
# L_away               float64
# W-L%_away            float64
# PF_away              float64
# PA_away              float64
# PD_away              float64
# MoV_away             float64
# SoS_away             float64
# ...

# %%
schedule_22.head()
# Out:
#   Week  Day       Date  Time           Winner/tie            Loser/tie  PtsW  \
# 0    1  Thu 2022-09-08     8        Buffalo Bills     Los Angeles Rams  31.0
# 1    1  Sun 2022-09-11     1   New Orleans Saints      Atlanta Falcons  27.0
# 2    1  Sun 2022-09-11     1     Cleveland Browns    Carolina Panthers  26.0
# 3    1  Sun 2022-09-11     1        Chicago Bears  San Francisco 49ers  19.0
# 4    1  Sun 2022-09-11     1  Pittsburgh Steelers   Cincinnati Bengals  23.0
#
#    PtsL   YdsW  TOW   YdsL  TOL                Home                 Away  \
# 0  10.0  413.0  4.0  243.0  3.0    Los Angeles Rams        Buffalo Bills
# 1  26.0  385.0  1.0  416.0  2.0     Atlanta Falcons   New Orleans Saints
# 2  24.0  355.0  0.0  261.0  1.0   Carolina Panthers     Cleveland Browns
# 3  10.0  204.0  1.0  331.0  2.0       Chicago Bears  San Francisco 49ers
# 4  20.0  267.0  0.0  432.0  5.0  Cincinnati Bengals  Pittsburgh Steelers
#
# ...

# %%
schedule_22.tail()
# Out:
#           Week  Day       Date  Time           Winner/tie  \
# 279   Division  Sun 2023-01-22     3   Cincinnati Bengals
# 280   Division  Sun 2023-01-22     6  San Francisco 49ers
# 281  ConfChamp  Sun 2023-01-29     3  Philadelphia Eagles
# 282  ConfChamp  Sun 2023-01-29     6   Kansas City Chiefs
# 283  SuperBowl  Sun 2023-02-12     6   Kansas City Chiefs
#
#                Loser/tie  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 279        Buffalo Bills  27.0  10.0  412.0  0.0  325.0  1.0
# 280       Dallas Cowboys  19.0  12.0  312.0  1.0  282.0  2.0
# 281  San Francisco 49ers  31.0   7.0  269.0  0.0  164.0  3.0
# 282   Cincinnati Bengals  23.0  20.0  357.0  1.0  309.0  2.0
# 283  Philadelphia Eagles  38.0  35.0  340.0  0.0  417.0  1.0
#
#                     Home                 Away  W_home  L_home  W-L%_home  \
# 279        Buffalo Bills   Cincinnati Bengals    13.0     3.0      0.813
# 280  San Francisco 49ers       Dallas Cowboys    13.0     4.0      0.765
# ...

# %%
print(schedule_23.loc[272])
# Out:
# Week               NaN
# Day                NaN
# Date          Playoffs
# Time               NaN
# Winner/tie         NaN
# Loser/tie          NaN
# PtsW               NaN
# PtsL               NaN
# YdsW               NaN
# TOW                NaN
# YdsL               NaN
# TOL                NaN
# Home               NaN
# Away               NaN
# W_home             NaN
# L_home             NaN
# W-L%_home          NaN
# PF_home            NaN
# PA_home            NaN
# PD_home            NaN
# MoV_home           NaN
# SoS_home           NaN
# OSRS_home          NaN
# DSRS_home          NaN
# W_away             NaN
# L_away             NaN
# W-L%_away          NaN
# PF_away            NaN
# PA_away            NaN
# PD_away            NaN
# MoV_away           NaN
# SoS_away           NaN
# OSRS_away          NaN
# DSRS_away          NaN
# Name: 272, dtype: object

# %%
schedule_23.drop(index=272, inplace=True)

# %%
schedule_23.reset_index(drop=True, inplace=True)

# %%
schedule_23["Date"] = pd.to_datetime(schedule_23["Date"])

# %%
schedule_23["Time"] = schedule_23["Time"].str.replace(":.+", "", regex=True).astype("int")

# %%
schedule_23.dtypes
# Out:
# Week                  object
# Day                   object
# Date          datetime64[ns]
# Time                   int32
# Winner/tie            object
# Loser/tie             object
# PtsW                 float64
# PtsL                 float64
# YdsW                 float64
# TOW                  float64
# YdsL                 float64
# TOL                  float64
# Home                  object
# Away                  object
# W_home               float64
# L_home               float64
# W-L%_home            float64
# PF_home              float64
# PA_home              float64
# PD_home              float64
# MoV_home             float64
# SoS_home             float64
# OSRS_home            float64
# DSRS_home            float64
# W_away               float64
# L_away               float64
# W-L%_away            float64
# PF_away              float64
# PA_away              float64
# PD_away              float64
# MoV_away             float64
# SoS_away             float64
# ...

# %%
schedule_23.head()
# Out:
#   Week  Day       Date  Time             Winner/tie           Loser/tie  PtsW  \
# 0    1  Thu 2023-09-07     8          Detroit Lions  Kansas City Chiefs  21.0
# 1    1  Sun 2023-09-10     1        Atlanta Falcons   Carolina Panthers  24.0
# 2    1  Sun 2023-09-10     1       Cleveland Browns  Cincinnati Bengals  24.0
# 3    1  Sun 2023-09-10     1   Jacksonville Jaguars  Indianapolis Colts  31.0
# 4    1  Sun 2023-09-10     1  Washington Commanders   Arizona Cardinals  20.0
#
#    PtsL   YdsW  TOW   YdsL  TOL                   Home                  Away  \
# 0  20.0  368.0  1.0  316.0  1.0     Kansas City Chiefs         Detroit Lions
# 1  10.0  221.0  0.0  281.0  3.0        Atlanta Falcons     Carolina Panthers
# 2   3.0  350.0  2.0  142.0  0.0       Cleveland Browns    Cincinnati Bengals
# 3  21.0  342.0  2.0  280.0  3.0     Indianapolis Colts  Jacksonville Jaguars
# 4  16.0  248.0  3.0  210.0  2.0  Washington Commanders     Arizona Cardinals
#
# ...

# %%
schedule_23.tail()
# Out:
#           Week  Day       Date  Time           Winner/tie  \
# 280   Division  Sun 2024-01-21     3        Detroit Lions
# 281   Division  Sun 2024-01-21     6   Kansas City Chiefs
# 282  ConfChamp  Sun 2024-01-28     3   Kansas City Chiefs
# 283  ConfChamp  Sun 2024-01-28     6  San Francisco 49ers
# 284  SuperBowl  Sun 2024-02-11     6   Kansas City Chiefs
#
#                 Loser/tie  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 280  Tampa Bay Buccaneers  31.0  23.0  391.0  0.0  408.0  2.0
# 281         Buffalo Bills  27.0  24.0  361.0  1.0  368.0  0.0
# 282      Baltimore Ravens  17.0  10.0  319.0  0.0  336.0  3.0
# 283         Detroit Lions  34.0  31.0  413.0  1.0  442.0  1.0
# 284   San Francisco 49ers  25.0  22.0  455.0  2.0  382.0  2.0
#
#                     Home                  Away  W_home  L_home  W-L%_home  \
# 280        Detroit Lions  Tampa Bay Buccaneers    12.0     5.0      0.706
# 281        Buffalo Bills    Kansas City Chiefs    11.0     6.0      0.647
# ...

# %%
schedule_22['Win_code'] = (schedule_22['Home'] == schedule_22['Winner/tie']).astype(int)

# %%
schedule_22.head()
# Out:
#   Week  Day       Date  Time           Winner/tie            Loser/tie  PtsW  \
# 0    1  Thu 2022-09-08     8        Buffalo Bills     Los Angeles Rams  31.0
# 1    1  Sun 2022-09-11     1   New Orleans Saints      Atlanta Falcons  27.0
# 2    1  Sun 2022-09-11     1     Cleveland Browns    Carolina Panthers  26.0
# 3    1  Sun 2022-09-11     1        Chicago Bears  San Francisco 49ers  19.0
# 4    1  Sun 2022-09-11     1  Pittsburgh Steelers   Cincinnati Bengals  23.0
#
#    PtsL   YdsW  TOW   YdsL  TOL                Home                 Away  \
# 0  10.0  413.0  4.0  243.0  3.0    Los Angeles Rams        Buffalo Bills
# 1  26.0  385.0  1.0  416.0  2.0     Atlanta Falcons   New Orleans Saints
# 2  24.0  355.0  0.0  261.0  1.0   Carolina Panthers     Cleveland Browns
# 3  10.0  204.0  1.0  331.0  2.0       Chicago Bears  San Francisco 49ers
# 4  20.0  267.0  0.0  432.0  5.0  Cincinnati Bengals  Pittsburgh Steelers
#
# ...

# %%
schedule_22['Home_code'] = schedule_22['Home'].astype('category').cat.codes

# %%
schedule_22['Away_code'] = schedule_22['Away'].astype('category').cat.codes

# %%
schedule_22.head()
# Out:
#   Week  Day       Date  Time           Winner/tie            Loser/tie  PtsW  \
# 0    1  Thu 2022-09-08     8        Buffalo Bills     Los Angeles Rams  31.0
# 1    1  Sun 2022-09-11     1   New Orleans Saints      Atlanta Falcons  27.0
# 2    1  Sun 2022-09-11     1     Cleveland Browns    Carolina Panthers  26.0
# 3    1  Sun 2022-09-11     1        Chicago Bears  San Francisco 49ers  19.0
# 4    1  Sun 2022-09-11     1  Pittsburgh Steelers   Cincinnati Bengals  23.0
#
#    PtsL   YdsW  TOW   YdsL  TOL                Home                 Away  \
# 0  10.0  413.0  4.0  243.0  3.0    Los Angeles Rams        Buffalo Bills
# 1  26.0  385.0  1.0  416.0  2.0     Atlanta Falcons   New Orleans Saints
# 2  24.0  355.0  0.0  261.0  1.0   Carolina Panthers     Cleveland Browns
# 3  10.0  204.0  1.0  331.0  2.0       Chicago Bears  San Francisco 49ers
# 4  20.0  267.0  0.0  432.0  5.0  Cincinnati Bengals  Pittsburgh Steelers
#
# ...

# %%
schedule_22.tail()
# Out:
#           Week  Day       Date  Time           Winner/tie  \
# 279   Division  Sun 2023-01-22     3   Cincinnati Bengals
# 280   Division  Sun 2023-01-22     6  San Francisco 49ers
# 281  ConfChamp  Sun 2023-01-29     3  Philadelphia Eagles
# 282  ConfChamp  Sun 2023-01-29     6   Kansas City Chiefs
# 283  SuperBowl  Sun 2023-02-12     6   Kansas City Chiefs
#
#                Loser/tie  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 279        Buffalo Bills  27.0  10.0  412.0  0.0  325.0  1.0
# 280       Dallas Cowboys  19.0  12.0  312.0  1.0  282.0  2.0
# 281  San Francisco 49ers  31.0   7.0  269.0  0.0  164.0  3.0
# 282   Cincinnati Bengals  23.0  20.0  357.0  1.0  309.0  2.0
# 283  Philadelphia Eagles  38.0  35.0  340.0  0.0  417.0  1.0
#
#                     Home                 Away  W_home  L_home  W-L%_home  \
# 279        Buffalo Bills   Cincinnati Bengals    13.0     3.0      0.813
# 280  San Francisco 49ers       Dallas Cowboys    13.0     4.0      0.765
# ...

# %%
schedule_22["Day_code"] = schedule_22["Date"].dt.dayofweek

# %%
schedule_22.head()
# Out:
#   Week  Day       Date  Time           Winner/tie            Loser/tie  PtsW  \
# 0    1  Thu 2022-09-08     8        Buffalo Bills     Los Angeles Rams  31.0
# 1    1  Sun 2022-09-11     1   New Orleans Saints      Atlanta Falcons  27.0
# 2    1  Sun 2022-09-11     1     Cleveland Browns    Carolina Panthers  26.0
# 3    1  Sun 2022-09-11     1        Chicago Bears  San Francisco 49ers  19.0
# 4    1  Sun 2022-09-11     1  Pittsburgh Steelers   Cincinnati Bengals  23.0
#
#    PtsL   YdsW  TOW   YdsL  TOL                Home                 Away  \
# 0  10.0  413.0  4.0  243.0  3.0    Los Angeles Rams        Buffalo Bills
# 1  26.0  385.0  1.0  416.0  2.0     Atlanta Falcons   New Orleans Saints
# 2  24.0  355.0  0.0  261.0  1.0   Carolina Panthers     Cleveland Browns
# 3  10.0  204.0  1.0  331.0  2.0       Chicago Bears  San Francisco 49ers
# 4  20.0  267.0  0.0  432.0  5.0  Cincinnati Bengals  Pittsburgh Steelers
#
# ...

# %%
schedule_23.head()
# Out:
#   Week  Day       Date  Time             Winner/tie           Loser/tie  PtsW  \
# 0    1  Thu 2023-09-07     8          Detroit Lions  Kansas City Chiefs  21.0
# 1    1  Sun 2023-09-10     1        Atlanta Falcons   Carolina Panthers  24.0
# 2    1  Sun 2023-09-10     1       Cleveland Browns  Cincinnati Bengals  24.0
# 3    1  Sun 2023-09-10     1   Jacksonville Jaguars  Indianapolis Colts  31.0
# 4    1  Sun 2023-09-10     1  Washington Commanders   Arizona Cardinals  20.0
#
#    PtsL   YdsW  TOW   YdsL  TOL                   Home                  Away  \
# 0  20.0  368.0  1.0  316.0  1.0     Kansas City Chiefs         Detroit Lions
# 1  10.0  221.0  0.0  281.0  3.0        Atlanta Falcons     Carolina Panthers
# 2   3.0  350.0  2.0  142.0  0.0       Cleveland Browns    Cincinnati Bengals
# 3  21.0  342.0  2.0  280.0  3.0     Indianapolis Colts  Jacksonville Jaguars
# 4  16.0  248.0  3.0  210.0  2.0  Washington Commanders     Arizona Cardinals
#
# ...

# %%
schedule_23["Day_code"] = schedule_23["Date"].dt.dayofweek

# %%
schedule_23['Home_code'] = schedule_23['Home'].astype('category').cat.codes

# %%
schedule_23['Away_code'] = schedule_23['Away'].astype('category').cat.codes

# %%
schedule_23['Win_code'] = (schedule_23['Home'] == schedule_23['Winner/tie']).astype(int)

# %%
schedule_23.head()
# Out:
#   Week  Day       Date  Time             Winner/tie           Loser/tie  PtsW  \
# 0    1  Thu 2023-09-07     8          Detroit Lions  Kansas City Chiefs  21.0
# 1    1  Sun 2023-09-10     1        Atlanta Falcons   Carolina Panthers  24.0
# 2    1  Sun 2023-09-10     1       Cleveland Browns  Cincinnati Bengals  24.0
# 3    1  Sun 2023-09-10     1   Jacksonville Jaguars  Indianapolis Colts  31.0
# 4    1  Sun 2023-09-10     1  Washington Commanders   Arizona Cardinals  20.0
#
#    PtsL   YdsW  TOW   YdsL  TOL                   Home                  Away  \
# 0  20.0  368.0  1.0  316.0  1.0     Kansas City Chiefs         Detroit Lions
# 1  10.0  221.0  0.0  281.0  3.0        Atlanta Falcons     Carolina Panthers
# 2   3.0  350.0  2.0  142.0  0.0       Cleveland Browns    Cincinnati Bengals
# 3  21.0  342.0  2.0  280.0  3.0     Indianapolis Colts  Jacksonville Jaguars
# 4  16.0  248.0  3.0  210.0  2.0  Washington Commanders     Arizona Cardinals
#
# ...

# %%
X_train = schedule_22[
    [
        'W_home', 'L_home', 'W-L%_home', 'PF_home', 'PA_home', 'PD_home',
        'MoV_home', 'SoS_home', 'OSRS_home', 'DSRS_home',
        'W_away', 'L_away', 'W-L%_away', 'PF_away', 'PA_away', 'PD_away',
        'MoV_away', 'SoS_away', 'OSRS_away', 'DSRS_away',
        'Day_code', 'Home_code', 'Away_code'
    ]
]

# %%
Y_train = schedule_22['Win_code']

# %%
X_test = schedule_23[
    [
        'W_home', 'L_home', 'W-L%_home', 'PF_home', 'PA_home', 'PD_home',
        'MoV_home', 'SoS_home', 'OSRS_home', 'DSRS_home',
        'W_away', 'L_away', 'W-L%_away', 'PF_away', 'PA_away', 'PD_away',
        'MoV_away', 'SoS_away', 'OSRS_away', 'DSRS_away',
        'Day_code', 'Home_code', 'Away_code'
    ]
]

# %%
Y_test = schedule_23['Win_code']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
schedule_23['Win_code_pred'] = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(Y_test, schedule_23['Win_code_pred'])

# %%
accuracy
# Out:
# 0.6596491228070176

# %%
combined = pd.DataFrame(dict(actual=schedule_23['Win_code'], prediction=schedule_23['Win_code_pred']))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction   0    1
# actual
# 0           69   55
# 1           42  119

# %%
 from sklearn.metrics import precision_score

# %%
precision_score(Y_test, schedule_23['Win_code_pred'])
# Out:
# 0.6839080459770115

# %%
schedule_24 = pd.read_csv('24_schedule.csv')

# %%
stats_24 = pd.read_csv('24_team_stats.csv')

# %%
schedule_24['Home'] = schedule_24.apply(
    lambda row: row['Loser/tie'] 
    if row['Unnamed: 5'] == '@' else row['Winner/tie'], 
    axis=1
)

# %%
schedule_24['Away'] = schedule_24.apply(
    lambda row: row['Winner/tie']
    if row['Unnamed: 5'] == '@' else row['Loser/tie'],
    axis=1
)

# %%
schedule_24.head()
# Out:
#    Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 0     1  Thu  2024-09-05  8:20PM   Kansas City Chiefs        NaN
# 1     1  Fri  2024-09-06  8:15PM  Philadelphia Eagles        NaN
# 2     1  Sun  2024-09-08  1:00PM  Pittsburgh Steelers          @
# 3     1  Sun  2024-09-08  1:00PM        Buffalo Bills        NaN
# 4     1  Sun  2024-09-08  1:00PM   New Orleans Saints        NaN
#
#            Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0   Baltimore Ravens   boxscore  27.0  20.0  353.0  1.0  452.0  1.0
# 1  Green Bay Packers   boxscore  34.0  29.0  410.0  3.0  414.0  1.0
# 2    Atlanta Falcons   boxscore  18.0  10.0  270.0  0.0  226.0  3.0
# 3  Arizona Cardinals   boxscore  34.0  28.0  352.0  1.0  270.0  1.0
# 4  Carolina Panthers   boxscore  47.0  10.0  379.0  1.0  193.0  3.0
#
#                   Home                 Away
# 0   Kansas City Chiefs     Baltimore Ravens
# 1  Philadelphia Eagles    Green Bay Packers
# ...

# %%
schedule_24.tail()
# Out:
#      Week  Day        Date    Time          Winner/tie Unnamed: 5  \
# 267    18  Sun  2025-01-05  1:00PM    Cleveland Browns          @
# 268    18  Sun  2025-01-05  1:00PM  Cincinnati Bengals          @
# 269    18  Sun  2025-01-05  1:00PM       Chicago Bears          @
# 270    18  Sun  2025-01-05  1:00PM   Carolina Panthers          @
# 271    18  Sun  2025-01-05  1:00PM       Buffalo Bills          @
#
#                 Loser/tie Unnamed: 7  PtsW  PtsL  YdsW  TOW  YdsL  TOL  \
# 267      Baltimore Ravens    preview   NaN   NaN   NaN  NaN   NaN  NaN
# 268   Pittsburgh Steelers    preview   NaN   NaN   NaN  NaN   NaN  NaN
# 269     Green Bay Packers    preview   NaN   NaN   NaN  NaN   NaN  NaN
# 270       Atlanta Falcons    preview   NaN   NaN   NaN  NaN   NaN  NaN
# 271  New England Patriots    preview   NaN   NaN   NaN  NaN   NaN  NaN
#
#                      Home                Away
# 267      Baltimore Ravens    Cleveland Browns
# 268   Pittsburgh Steelers  Cincinnati Bengals
# ...

# %%
stats_24['Tm'] = stats_24['Tm'].str.replace(r'[\*\+]', '', regex=True)

# %%
stats_24.head()
# Out:
#                      Tm   W   L   W-L%   PF   PA   PD  MoV  SoS   SRS  OSRS  \
# 0         Buffalo Bills  11   3  0.786  445  310  135  9.6  0.4  10.1   9.4
# 1        Miami Dolphins   6   8  0.429  276  312  -36 -2.6 -0.9  -3.5  -3.8
# 2         New York Jets   4  10  0.286  283  325  -42 -3.0 -0.3  -3.3  -2.3
# 3  New England Patriots   3  11  0.214  238  337  -99 -7.1 -1.8  -8.9  -6.4
# 4   Pittsburgh Steelers  10   4  0.714  336  265   71  5.1 -1.5   3.6   0.6
#
#    DSRS
# 0   0.7
# 1   0.3
# 2  -1.0
# 3  -2.5
# 4   3.0

# %%
to_merge = stats_24[['Tm', 'W', 'L', 'W-L%', 'PF', 'PA', 'PD', 'MoV', 'SoS', 'OSRS', 'DSRS']]

# %%
schedule_24 = schedule_24.merge(to_merge, how='left', left_on='Home', right_on='Tm', suffixes=('', '_home'))

# %%
schedule_24 = schedule_24.merge(to_merge, how='left', left_on='Away', right_on='Tm', suffixes=('_home', '_away'))

# %%
schedule_24.head()
# Out:
#    Week  Day        Date    Time           Winner/tie Unnamed: 5  \
# 0     1  Thu  2024-09-05  8:20PM   Kansas City Chiefs        NaN
# 1     1  Fri  2024-09-06  8:15PM  Philadelphia Eagles        NaN
# 2     1  Sun  2024-09-08  1:00PM  Pittsburgh Steelers          @
# 3     1  Sun  2024-09-08  1:00PM        Buffalo Bills        NaN
# 4     1  Sun  2024-09-08  1:00PM   New Orleans Saints        NaN
#
#            Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  \
# 0   Baltimore Ravens   boxscore  27.0  20.0  353.0  1.0  452.0  1.0
# 1  Green Bay Packers   boxscore  34.0  29.0  410.0  3.0  414.0  1.0
# 2    Atlanta Falcons   boxscore  18.0  10.0  270.0  0.0  226.0  3.0
# 3  Arizona Cardinals   boxscore  34.0  28.0  352.0  1.0  270.0  1.0
# 4  Carolina Panthers   boxscore  47.0  10.0  379.0  1.0  193.0  3.0
#
#                   Home                 Away              Tm_home  W_home  \
# 0   Kansas City Chiefs     Baltimore Ravens   Kansas City Chiefs      13
# ...

# %%
schedule_24.tail()
# Out:
#      Week  Day        Date    Time          Winner/tie Unnamed: 5  \
# 267    18  Sun  2025-01-05  1:00PM    Cleveland Browns          @
# 268    18  Sun  2025-01-05  1:00PM  Cincinnati Bengals          @
# 269    18  Sun  2025-01-05  1:00PM       Chicago Bears          @
# 270    18  Sun  2025-01-05  1:00PM   Carolina Panthers          @
# 271    18  Sun  2025-01-05  1:00PM       Buffalo Bills          @
#
#                 Loser/tie Unnamed: 7  PtsW  PtsL  YdsW  TOW  YdsL  TOL  \
# 267      Baltimore Ravens    preview   NaN   NaN   NaN  NaN   NaN  NaN
# 268   Pittsburgh Steelers    preview   NaN   NaN   NaN  NaN   NaN  NaN
# 269     Green Bay Packers    preview   NaN   NaN   NaN  NaN   NaN  NaN
# 270       Atlanta Falcons    preview   NaN   NaN   NaN  NaN   NaN  NaN
# 271  New England Patriots    preview   NaN   NaN   NaN  NaN   NaN  NaN
#
#                      Home                Away               Tm_home  W_home  \
# ...

# %%
schedule_24.drop(columns=['Unnamed: 7', 'Unnamed: 5', 'Tm_home', 'Tm_away'], inplace=True)

# %%
schedule_24.tail()
# Out:
#      Week  Day        Date    Time          Winner/tie             Loser/tie  \
# 267    18  Sun  2025-01-05  1:00PM    Cleveland Browns      Baltimore Ravens
# 268    18  Sun  2025-01-05  1:00PM  Cincinnati Bengals   Pittsburgh Steelers
# 269    18  Sun  2025-01-05  1:00PM       Chicago Bears     Green Bay Packers
# 270    18  Sun  2025-01-05  1:00PM   Carolina Panthers       Atlanta Falcons
# 271    18  Sun  2025-01-05  1:00PM       Buffalo Bills  New England Patriots
#
#      PtsW  PtsL  YdsW  TOW  YdsL  TOL                  Home  \
# 267   NaN   NaN   NaN  NaN   NaN  NaN      Baltimore Ravens
# 268   NaN   NaN   NaN  NaN   NaN  NaN   Pittsburgh Steelers
# 269   NaN   NaN   NaN  NaN   NaN  NaN     Green Bay Packers
# 270   NaN   NaN   NaN  NaN   NaN  NaN       Atlanta Falcons
# 271   NaN   NaN   NaN  NaN   NaN  NaN  New England Patriots
#
#                    Away  W_home  L_home  W-L%_home  PF_home  PA_home  PD_home  \
# ...

# %%
schedule_24["Date"] = pd.to_datetime(schedule_24["Date"])

# %%
schedule_24["Time"] = schedule_24["Time"].str.replace(":.+", "", regex=True).astype("int")

# %%
import numpy as np

# %%
cutoff_date = pd.Timestamp("2024-12-21")

# %%
schedule_24['Win_code'] = np.where(
    schedule_24['Date'] < cutoff_date,
    (schedule_24['Home'] == schedule_24['Winner/tie']).astype(int), None
)

# %%
schedule_24
# Out:
#      Week  Day       Date  Time           Winner/tie             Loser/tie  \
# 0       1  Thu 2024-09-05     8   Kansas City Chiefs      Baltimore Ravens
# 1       1  Fri 2024-09-06     8  Philadelphia Eagles     Green Bay Packers
# 2       1  Sun 2024-09-08     1  Pittsburgh Steelers       Atlanta Falcons
# 3       1  Sun 2024-09-08     1        Buffalo Bills     Arizona Cardinals
# 4       1  Sun 2024-09-08     1   New Orleans Saints     Carolina Panthers
# ..    ...  ...        ...   ...                  ...                   ...
# 267    18  Sun 2025-01-05     1     Cleveland Browns      Baltimore Ravens
# 268    18  Sun 2025-01-05     1   Cincinnati Bengals   Pittsburgh Steelers
# 269    18  Sun 2025-01-05     1        Chicago Bears     Green Bay Packers
# 270    18  Sun 2025-01-05     1    Carolina Panthers       Atlanta Falcons
# 271    18  Sun 2025-01-05     1        Buffalo Bills  New England Patriots
#
#      PtsW  PtsL   YdsW  TOW   YdsL  TOL                  Home  \
# ...

# %%
schedule_24['Home_code'] = schedule_24['Home'].astype('category').cat.codes

# %%
schedule_24['Away_code'] = schedule_24['Away'].astype('category').cat.codes

# %%
schedule_24["Day_code"] = schedule_24["Date"].dt.dayofweek

# %%
X_future = schedule_24[
    [
        'W_home', 'L_home', 'W-L%_home', 'PF_home', 'PA_home', 'PD_home',
        'MoV_home', 'SoS_home', 'OSRS_home', 'DSRS_home',
        'W_away', 'L_away', 'W-L%_away', 'PF_away', 'PA_away', 'PD_away',
        'MoV_away', 'SoS_away', 'OSRS_away', 'DSRS_away',
        'Day_code', 'Home_code', 'Away_code'
    ]
]

# %%
schedule_24['Win_code_pred'] = model.predict(X_future)

# %%
schedule_24.tail()
# Out:
#      Week  Day       Date  Time          Winner/tie             Loser/tie  \
# 267    18  Sun 2025-01-05     1    Cleveland Browns      Baltimore Ravens
# 268    18  Sun 2025-01-05     1  Cincinnati Bengals   Pittsburgh Steelers
# 269    18  Sun 2025-01-05     1       Chicago Bears     Green Bay Packers
# 270    18  Sun 2025-01-05     1   Carolina Panthers       Atlanta Falcons
# 271    18  Sun 2025-01-05     1       Buffalo Bills  New England Patriots
#
#      PtsW  PtsL  YdsW  TOW  YdsL  TOL                  Home  \
# 267   NaN   NaN   NaN  NaN   NaN  NaN      Baltimore Ravens
# 268   NaN   NaN   NaN  NaN   NaN  NaN   Pittsburgh Steelers
# 269   NaN   NaN   NaN  NaN   NaN  NaN     Green Bay Packers
# 270   NaN   NaN   NaN  NaN   NaN  NaN       Atlanta Falcons
# 271   NaN   NaN   NaN  NaN   NaN  NaN  New England Patriots
#
#                    Away  W_home  L_home  W-L%_home  PF_home  PA_home  PD_home  \
# ...

# %%
analysis = schedule_24.loc[225]

# %%
print(analysis)
# Out:
# Week                              16
# Day                              Sat
# Date             2024-12-21 00:00:00
# Time                               1
# Winner/tie            Houston Texans
# Loser/tie         Kansas City Chiefs
# PtsW                             NaN
# PtsL                             NaN
# YdsW                             NaN
# TOW                              NaN
# YdsL                             NaN
# TOL                              NaN
# Home              Kansas City Chiefs
# Away                  Houston Texans
# W_home                            13
# L_home                             1
# W-L%_home                      0.929
# PF_home                          329
# PA_home                          259
# PD_home                           70
# MoV_home                         5.0
# SoS_home                        -0.7
# OSRS_home                       -0.2
# DSRS_home                        4.5
# W_away                             9
# ...

# %%
print(schedule_24.loc[224])
# Out:
# Week                               16
# Day                               Thu
# Date              2024-12-19 00:00:00
# Time                                8
# Winner/tie       Los Angeles Chargers
# Loser/tie              Denver Broncos
# PtsW                             34.0
# PtsL                             27.0
# YdsW                            380.0
# TOW                               1.0
# YdsL                            355.0
# TOL                               0.0
# Home             Los Angeles Chargers
# Away                   Denver Broncos
# W_home                              9
# L_home                              6
# W-L%_home                         0.6
# PF_home                           328
# PA_home                           274
# PD_home                            54
# MoV_home                          3.6
# SoS_home                         -0.5
# OSRS_home                        -1.4
# DSRS_home                         4.4
# W_away                              9
# ...

# %%
start_row = 225

# %%
useful_columns = ['Date', 'Home', 'Away', 'Win_code_pred']

# %%
output_file = "24_predictions_from_2024_12_21.csv"

# %%
schedule_24.iloc[start_row:][useful_columns].to_csv(output_file, index=False)
